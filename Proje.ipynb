# %%
isim = input("Adınızı giriniz : ")
soy_isim = input("Soyadınızı giriniz : ")
sayac = 0
ders_sayacı = 3 
while sayac<3:
    giris_isim = input("Öğrencinin Adı : ")
    giris_soyisim = input("Öğrencinin Soyadı : ")

    if giris_isim == isim.lower() and giris_soyisim==soy_isim.lower():
        print("Hoşgeldin {} {}".format(isim,soy_isim))
        break
    else:
        print("Hatalı giriş lütfen daha sonra tekrar deneyiniz!\nKalan giriş hakkınız {}".format(i))
        i+=1
        if(i==3):
            print("Lütfen daha sonra tekrar deneyiniz!!!")
            exit()
            
if( ders_sayacı != 0):
    dersler = ["Machine Learning","Python","Javascript","R","Statistics","Algebra","Math"]
    secilenler = list()
    print("En az 3, en fazla 5 ders seçiniz.\n")
    for i in range(len(dersler)):
        print(str(i+1) + ". "+ dersler[i] )
    print("\n")
    
    for i in range(len(dersler)):
        if(len(secilenler)!=5):
            istenen_ders = int(input(str(i+1)+". seçilen(0:seçimi tamamlar): "))
            if(istenen_ders>=0 and istenen_ders<8):
                if(istenen_ders ==0 and len(secilenler)>=3):
                    break
                elif(istenen_ders ==0 and len(secilenler)<3):
                    print("\nEn az 3, en fazla 5 ders seçebilirsiniz!\n\n")
                    break 
                secilenler.append(dersler[istenen_ders-1])
            else:
                print("Var olan dersin kodunu girin!\n")
        else:
            print("En fazla 5 ders alabilirsiniz!!\n")
            break
            
    if(len(secilenler)>=3):
        print("\n") 
        for i in range(len(secilenler)):
            print(str(i+1) + ". "+ secilenler[i] )
        sınav = int(input("Hangi dersin ortalaması hesaplansın?\n")) 
        secilen_sınav = secilenler[sınav-1]
        vize = int(input("Vize notunuz "+secilen_sınav+" : "))
        final = int(input("Final notunuz "+secilen_sınav+" : "))
        proje = int(input("Proje notunuz "+secilen_sınav+" : "))
        ortalama = (vize * 0.3) + (final * 0.5) + (proje * 0.2)
        print("\n Ortalamanız: "+ str(ortalama))
        if(ortalama >= 90):
            print("AA")
        elif(ortalama >=70 and ortalama<90):
             print("BB")
        elif(ortalama >=50 and ortalama<70):
             print("CC")
        elif(ortalama >=30 and ortalama<50):
             print("DD")
        elif(ortalama <30):
            print("FF")
